# %% [markdown]
# <a href="https://colab.research.google.com/github/anniemajella/jenkins/blob/main/image_contours.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image1 = cv2.imread('/content/puppy.jpg')
image = cv2.cvtColor(image1,cv2.COLOR_BGR2GRAY)

# %%
blurred=cv2.GaussianBlur(image,(11,11),0)
edged=cv2.Canny(blurred,30,150)
cnts,_=cv2.findContours(edged.copy(),cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)
coins=image.copy()

# %%
cv2.drawContours(coins,cnts,-1,(0,255,0),3)
plt.imshow(coins)

# %%
plt.imshow(cv2.cvtColor(image1,cv2.COLOR_BGR2RGB))

# %%
plt.imshow(edged)
